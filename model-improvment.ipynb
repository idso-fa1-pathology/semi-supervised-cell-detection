# %%
# !nvidia-smi
# Out:
# Mon Feb 26 17:58:36 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.199.02   Driver Version: 470.199.02   CUDA Version: 12.3     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  On   | 00000000:0F:00.0 Off |                    0 |
# | N/A   26C    P0    52W / 400W |      3MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.230 🚀 Python-3.11.0rc1 torch-2.1.2+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40536MiB)
# Setup complete ✅ (256 CPUs, 1007.7 GB RAM, 1055.9/1757.8 GB disk)

# %%
# !yolo train model=yolov8x.pt data="/rsrch5/home/plm/yshokrollahi/project4/dataset/config.yaml" epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.230 🚀 Python-3.11.0rc1 torch-2.1.2+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40536MiB)
# ...

# %% [markdown]
# Round 2

# %%
# !yolo train model=yolov8x.pt data="/rsrch5/home/plm/yshokrollahi/project4/dataset-2/config.yaml" epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.230 🚀 Python-3.11.0rc1 torch-2.1.2+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40536MiB)
# ...

# %% [markdown]
# Round 3

# %%
# !yolo train model=yolov8x.pt data="/rsrch5/home/plm/yshokrollahi/project4/dataset-3/config.yaml" epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.230 🚀 Python-3.11.0rc1 torch-2.1.2+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40536MiB)
# ...
