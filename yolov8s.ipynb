# %%
# !nvidia-smi
# Out:
# Mon Jan 29 12:28:35 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.129.03             Driver Version: 535.129.03   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 4090        Off | 00000000:41:00.0 Off |                  Off |
# | 30%   36C    P8              36W / 480W |    581MiB / 24564MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# # Stage 1

# %%
# !yolo train model=yolov8x.pt data="/rsrch5/home/plm/yshokrollahi/dataset_nwa/config.yaml" epochs=250 imgsz=640 patience=500
# Out:
# Ultralytics YOLOv8.0.225 🚀 Python-3.8.18 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24215MiB)
# ...

# %% [markdown]
# # Stage 2

# %%
# !yolo train model=yolov8x.pt data="/rsrch5/home/plm/yshokrollahi/dataset_nwa_one/config.yaml" epochs=10 imgsz=640 patience=500
# Out:
# Ultralytics YOLOv8.0.225 🚀 Python-3.8.18 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24215MiB)
# ...

# %% [markdown]
# # stage 3 run 24

# %%
# !yolo train model=yolov8x.pt data="/rsrch5/home/plm/yshokrollahi/dataset_nwa_two/config.yaml" epochs=10 imgsz=640 patience=500
# Out:
# Ultralytics YOLOv8.0.225 🚀 Python-3.8.18 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24215MiB)
# ...

# %% [markdown]
# # Run 25_38_250///

# %%
# !yolo train model=yolov8x.pt data="/rsrch5/home/plm/yshokrollahi/dataset_nwa_three/config.yaml" batch=8 dropout=0.4 epochs=3  imgsz=640 patience=500
# Out:
# Ultralytics YOLOv8.0.225 🚀 Python-3.8.18 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24215MiB)
# ...

# %%
# !yolo train model=yolov8x.pt data="/rsrch5/home/plm/yshokrollahi/dataset_nwa_four/config.yaml" epochs=100 batch=4 dropout=0.2 imgsz=640 patience=500
# Out:
# Ultralytics YOLOv8.0.225 🚀 Python-3.8.18 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24215MiB)
# ...

# %%
# !yolo train model=yolov8x.pt data="/rsrch5/home/plm/yshokrollahi/dataset_nwa_four/config.yaml" epochs=1000 batch=8 imgsz=640 patience=500
# Out:
# Ultralytics YOLOv8.0.225 🚀 Python-3.8.18 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24215MiB)
# ...

# %%
# !yolo train resume model="/rsrch5/home/plm/yshokrollahi/runs/detect/train43/weights/last.pt"
# Out:
# Ultralytics YOLOv8.0.225 🚀 Python-3.8.18 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24215MiB)
# ...

# %%
# !yolo train resume model="/rsrch5/home/plm/yshokrollahi/runs/detect/train432/weights/last.pt"
# Out:
# Ultralytics YOLOv8.0.225 🚀 Python-3.8.18 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24215MiB)
# ...

# %%
# !yolo train model=yolov8x.pt data="/rsrch5/home/plm/yshokrollahi/dataset_nwa_four/config.yaml" epochs=10 batch=8 dropout=0.2 imgsz=640 patience=500
# Out:
# Ultralytics YOLOv8.0.225 🚀 Python-3.8.18 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24215MiB)
# ...

# %% [markdown]
# # dATA SET VAL

# %%
# !yolo train model=yolov8x.pt data="/rsrch5/home/plm/yshokrollahi/dataset_val/config.yaml" epochs=100 batch=4 dropout= 0.2 imgsz=640 patience=500
# Out:
# Ultralytics YOLOv8.0.225 🚀 Python-3.8.18 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24215MiB)
# ...

# %%
# !yolo train model=yolov8x.pt data="/rsrch5/home/plm/yshokrollahi/dataset_val/config.yaml" epochs=1000 batch=4 dropout= 0.2 imgsz=640 patience=500
# Out:
# Ultralytics YOLOv8.0.225 🚀 Python-3.8.18 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24215MiB)
# ...
